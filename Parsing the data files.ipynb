# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import time
import os

# %%
list_of_files = !ls *xlsx

# %%
list_of_files
# Out:
# ['pedestrianfootfall2007.xlsx',
#  'pedestrianfootfall2008.xlsx',
#  'pedestrianfootfall2009.xlsx',
#  'pedestrianfootfall2010.xlsx',
#  'pedestrianfootfall2011.xlsx',
#  'pedestrianfootfall2012.xlsx',
#  'pedestrianfootfall2013.xlsx']

# %%
#Check to see the different entrances that we need to get the data for
worksheet = 'Week 53(2013) -  Week 1 (2014)'
week = pd.read_excel(list_of_files[0], sheet=worksheet)

week.set_index(week.columns[0],inplace=True)            


entrances = week.index[week.index.str.match('Entra',na=False)]
for entrance in entrances:
    print(entrance)
# Out:
# Entrance Name: O'Connell Street at Clerys
# Entrance Name: Grafton St at Card Gallery
# Entrance Name: Grafton St at M&S
# Entrance Name: O'Connell Street at Easons
# Entrance Name: Henry Street at Butlers
# Entrance Name: Grafton St at Korkys

# %%
x_headers = ["Time","Mon:In","Mon:Out","Tues:In","Tues:Out","Weds:In","Weds:Out",
           "Thurs:In","Thurs:Out","Fri:In","Fri:Out","Sat:In","Sat:Out","Sun:In","Sun:Out","Entrance","Sheet Number"]

stuff_heads = ['Mon:In', 'Mon:Out', 'Tues:In', 'Tues:Out', 'Weds:In', 'Weds:Out', 'Thurs:In', 'Thurs:Out', 'Fri:In', 
            'Fri:Out', 'Sat:In', 'Sat:Out', 'Sun:In', 'Sun:Out']

list_of_files = !ls *xlsx

for file in list_of_files:
 
    input_file = file
    output_file = input_file.split('.')[0] + '.csv'


    df = pd.read_excel(input_file, sheet_name=None)

    
    for key, value in df.items():
        #print(key)
        worksheet = key
    
    week = pd.read_excel(input_file, sheet=worksheet)
    week.set_index(week.columns[0],inplace=True)            
    print(week.columns[0])
    entrances = week.index[week.index.str.match('Entra',na=False)]
    
    
    #for entrance in entrances:
    #    print(entrance) 
    print(len(entrances))
    #print(worksheet)
    #print(input_file)
    alley_cat = pd.DataFrame()
    for key, value in df.items():

        try:
            if value.columns[0] == "Unnamed: 0":    
                value = value.drop("Unnamed: 0", axis=1)
                print("drop it like its hot")
                #print(value.columns[0])
                #print(value.columns[1])
        except:
            print("No need to drop column")

        try:
            #print("Try reset index")
            value.reset_index(drop=True)
        except:
            print("Could not set index")


        #print(value.columns)
        #print(value.columns[0])   
        try:
            #print("Try and set the index")
            value.set_index(value.columns[0],inplace=True)            
        except:
            print("Couldn't set the index so break")
            break

        test_ent = "Entrance Name: O'Connell Street at Clerys"

        try:
            position = value.index.get_loc(test_ent)
            #print("test ok for: " +str(key))
        except:
            print("test FAILED for: " +str(key))
            #value.set_index(value.columns[1],inplace=True)

        entrances = value.index[value.index.str.match('Entra',na=False)]

        data=[]  

        for entrance in entrances:

            #Initialise array for this entrance
            stuff = []
            ent = entrance.split(":")
            ent = ent[-1].lstrip()
            try:
                position = value.index.get_loc(entrance)
                #print("Position" +str(position))
            except:
                print("problem with position")

            stuff = pd.DataFrame(value.iloc[position+3:position+27, 0:14])
            #print(stuff)
            stuff.reset_index()
            stuff.columns = stuff_heads
            stuff['Entrance'] = ent
            stuff['Sheet Number'] = key
            stuff['Time'] = stuff.index.tolist()
            data.append(stuff)
        alley_cat = alley_cat.append(data,ignore_index=True)

        
    m = pd.melt(alley_cat, id_vars=['Sheet Number', 'Entrance', 'Time'], var_name='Day/Direction')
    m['Day'] = m['Day/Direction'].str.split(':').str[0]
    m['Direction'] = m['Day/Direction'].str.split(':').str[-1]
    m = m.drop('Day/Direction', axis=1)
    x = m.pop('value')
    m['Value'] = x
    m.to_csv(output_file, index=False)
    print(output_file)
# Out:
# Unnamed: 1
# 6
# No need to drop column
# Couldn't set the index so break
# pedestrianfootfall2007.csv
# Unnamed: 1
# 6
# pedestrianfootfall2008.csv
# Unnamed: 1
# 6
# pedestrianfootfall2009.csv
# Unnamed: 1
# 6
# pedestrianfootfall2010.csv
# Unnamed: 1
# 6
# pedestrianfootfall2011.csv
# Unnamed: 1
# 13
# test FAILED for: Week_16
# test FAILED for: Week_17
# pedestrianfootfall2012.csv
# Unnamed: 1
# 13
# pedestrianfootfall2013.csv

# %%
value.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %% [markdown]
# alley_cat['Entrance'].value_counts()

# %% [markdown]
# alley_cat['Sheet Number'].value_counts()

# %%
for col in alley_cat.columns:
    print(col)
    print(alley_cat[col].max())        
    print(alley_cat[col].mean())
    print(alley_cat[col].std())
    print(alley_cat[col].sum())
# Out:
# Mon:In
# 16109
# 2637.7458071278825
# 2827.2354214916377
# 20131276
# Mon:Out
# 0
# 0.0
# 0.0
# 0
# Tues:In
# 18799
# 2758.0344601677148
# 2840.568336139063
# 21049319
# Tues:Out
# 0
# 0.0
# 0.0
# 0
# Weds:In
# 14478
# 2874.6409853249475
# 2923.8837171906207
# 21939260
# Weds:Out
# 0
# 0.0
# 0.0
# 0
# Thurs:In
# 14941
# 3071.162997903564
# 3130.7014315395722
# 23439116
# Thurs:Out
# 0
# 0.0
# 0.0
# 0
# Fri:In
# 17828
# 3122.117531446541
# 3187.3759783329406
# 23828001
# Fri:Out
# 0
# 0.0
# 0.0
# 0
# Sat:In
# 16517
# 3402.230214884696
# 3651.4916249680346
# 25965821
# Sat:Out
# 0
# 0.0
# 0.0
# 0
# Sun:In
# 13555
# 2170.130110062893
# 2389.5691715356884
# 16562433
# Sun:Out
# 0
# 0.0
# 0.0
# 0
# Entrance
# O'Connell Street at Easons
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     818         try:
# --> 819             x = float(x)
#     820         except Exception:
#
# ValueError: could not convert string to float: "O'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Ca ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     821             try:
# --> 822                 x = complex(x)
#     823             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     355     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 356     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     357
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     824                 raise TypeError('Could not convert {value!s} to numeric'
# --> 825                                 .format(value=x))
#     826     return x
#
# TypeError: Could not convert O'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton S ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     818         try:
# --> 819             x = float(x)
#     820         except Exception:
#
# ValueError: could not convert string to float: "O'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Ca ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     821             try:
# --> 822                 x = complex(x)
#     823             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-281-f814e626ce88> in <module>()
#       2     print(col)
#       3     print(alley_cat[col].max())
# ----> 4     print(alley_cat[col].mean())
#       5     print(alley_cat[col].std())
#       6     print(alley_cat[col].sum())
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    7313                                       skipna=skipna)
#    7314         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 7315                             numeric_only=numeric_only)
#    7316
#    7317     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2575                                           'numeric_only.'.format(name))
#    2576             with np.errstate(all='ignore'):
# -> 2577                 return op(delegate, skipna=skipna, **kwds)
#    2578
#    2579         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     129             except Exception:
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#     133                     # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     354         dtype_count = dtype
#     355     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 356     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     357
#     358     if axis is not None and getattr(the_sum, 'ndim', False):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     823             except Exception:
#     824                 raise TypeError('Could not convert {value!s} to numeric'
# --> 825                                 .format(value=x))
#     826     return x
#     827
#
# TypeError: Could not convert O'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at Card GalleryGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SGrafton St at M&SO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsO'Connell Street at EasonsHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersHenry Street at ButlersGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysGrafton St at KorkysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysO'Connell Street at ClerysGrafton St at Card GalleryGrafton S ...

# %%
m = pd.melt(alley_cat, id_vars=['Sheet Number', 'Entrance', 'Time'], var_name='Day/Direction')

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106848 entries, 0 to 106847
# Data columns (total 5 columns):
# Sheet Number     106848 non-null object
# Entrance         106848 non-null object
# Time             106848 non-null object
# Day/Direction    106848 non-null object
# value            106848 non-null object
# dtypes: object(5)
# memory usage: 4.1+ MB

# %%
m.describe()
# Out:
#        Sheet Number                 Entrance      Time Day/Direction   value
# count        106848                   106848    106848        106848  106848
# unique           53                        6        24            14   10498
# top         Week_30  Henry Street at Butlers  19:00:00       Sun:Out       0
# freq           2016                    17808      4452          7632   54177

# %%
m['Day'] = m['Day/Direction'].str.split(':').str[0]

# %%
m['Direction'] = m['Day/Direction'].str.split(':').str[-1]

# %%
m.head(2)
# Out:
#   Sheet Number                    Entrance      Time Day/Direction value  Day  \
# 0  Week_1_2008  O'Connell Street at Clerys  00:00:00        Mon:In     0  Mon
# 1  Week_1_2008  O'Connell Street at Clerys  01:00:00        Mon:In     0  Mon
#
#   Direction
# 0        In
# 1        In

# %%
m = m.drop('Day/Direction', axis=1)

# %%
x = m.pop('value')

# %%
m['Value'] = x

# %%
m.head(2)
# Out:
#   Sheet Number                    Entrance      Time  Day Direction Value
# 0  Week_1_2008  O'Connell Street at Clerys  00:00:00  Mon        In     0
# 1  Week_1_2008  O'Connell Street at Clerys  01:00:00  Mon        In     0

# %%
m.to_csv(output_file)
